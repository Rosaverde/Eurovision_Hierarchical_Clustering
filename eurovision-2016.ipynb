# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import linkage, dendrogram

# %%
df = pd.read_csv('https://raw.githubusercontent.com/matzim95/ML-datasets/master/eurovision-2016.csv')
df = df.pivot(index='From country', columns='To country')['Jury Rank']
df.head(3)
# Out:
# To country    Armenia  Australia  Austria  Azerbaijan  Belgium  Bulgaria  \
# From country
# Albania          15.0        1.0     16.0        13.0     25.0       7.0
# Armenia           NaN        6.0     22.0        25.0      7.0       4.0
# Australia        13.0        NaN     24.0        12.0      1.0       3.0
#
# To country    Croatia  Cyprus  Czech Republic  France  ...  Lithuania  Malta  \
# From country                                           ...
# Albania          21.0    23.0            22.0     2.0  ...       20.0    9.0
# Armenia          15.0     5.0            10.0     1.0  ...       14.0    3.0
# Australia        10.0    20.0            16.0     5.0  ...        4.0   21.0
#
# To country    Poland  Russia  Serbia  Spain  Sweden  The Netherlands  Ukraine  \
# From country
# Albania         14.0     4.0    19.0    5.0    11.0             24.0     12.0
# Armenia         23.0     9.0    12.0    8.0    17.0             11.0     16.0
# ...

# %%
df.isnull().sum().sum()
# Out:
# 26

# %%
df = df.fillna(0)

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ### Hierarchical clustering

# %%
merg = linkage(df, method='complete')

dendrogram(merg, labels = df.index, leaf_rotation= 90, leaf_font_size = 6, color_threshold=0.7*max(merg[:,2]))
plt.show()

# %%
merg = linkage(df, method='single')

dendrogram(merg, labels = df.index, leaf_rotation= 90,  color_threshold=0.8*max(merg[:,2]))
plt.show()
